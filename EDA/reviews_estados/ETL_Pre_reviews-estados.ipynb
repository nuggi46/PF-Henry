# %% [markdown]
# #<b><center>ETL Preliminar reviews-estados</b></center>

# %% [markdown]
# Importacion de librerías

# %%
from google.colab import drive

# %% [markdown]
# Montando carpeta drive.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Copiando el contenido de data lake en ruta //yelp-and-maps-data-lake/reviews-estados hacia carpeta personal de drive /content/drive/MyDrive/datalake/reviews-estados . Este proceso solo se realiza una vez, de lo contrario se duplicaran copias. Peso total de archivos 658.5 Mb

# %%
# !gsutil -m cp -r gs://yelp-and-maps-data-lake/reviews-estados /content/drive/MyDrive/datalake/reviews-estados
# Out:
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/13.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/16.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/14.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/15.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/2.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/12.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/10.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/11.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/1.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/3.json...
# Copying gs://yelp-and-maps-data-lake/reviews-estados/review-Pennsylvania/4.json...
# ...
