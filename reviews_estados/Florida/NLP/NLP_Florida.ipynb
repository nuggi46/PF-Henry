# %% [markdown]
# #<b><center>NLP Florida</b></center>

# %% [markdown]
# Importacion de librerías

# %%
from google.colab import drive
import pandas as pd
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Montando carpeta drive.

# %%
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/datalake/reviews-estados/review-Florida
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/datalake/reviews-estados/review-Florida

# %%
df = pd.read_parquet('reviews.parquet')
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643057 entries, 0 to 1643056
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1643057 non-null  float64
#  1   gmap_id  1643057 non-null  object
#  2   text     1643057 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 37.6+ MB
#         user_id                                gmap_id  \
# 0  1.067380e+20  0x88c2c11c79cc1281:0x9a6589fa9704fc97
# 1  1.000709e+20  0x88c2c11c79cc1281:0x9a6589fa9704fc97
# 2  1.138442e+20  0x88c2c11c79cc1281:0x9a6589fa9704fc97
# 3  1.015351e+20  0x88c2c11c79cc1281:0x9a6589fa9704fc97
# 4  1.011500e+20  0x88c2c11c79cc1281:0x9a6589fa9704fc97
#
#                                                 text
# 0                     The chip and queso is the best
# 1                                     Very good food
# 2     I love tijuana flats.  Always have always will
# 3  Rays strike out 10 batters and lunch is on the...
# 4  I wouldn't call this a mexican restaurant is m...

# %%
textos = df['text']
textos.tail()
# Out:
# 1643052             Best seafood in town
# 1643053         Awesome food and staff!!
# 1643054             Good food good price
# 1643055    Good seafood at a fair price.
# 1643056                   Love the place
# Name: text, dtype: object

# %% [markdown]
# <b>Tokenización</b>
#
# Se eliminan signos de puntuación y se toma la raíz de las palabras. Se tokeniza el texto de los reviews.

# %%
# Initialize empty array
# to append clean text
corpus = []
for texto in textos:

    # column : "Review", row ith
    review = re.sub('[^a-zA-Z]', ' ', texto)

    # convert all cases to lower cases
    review = review.lower()

    # split to array(default delimiter is " ")
    review = review.split()

    # creating PorterStemmer object to
    # take main stem of each word
    ps = PorterStemmer()

    # loop for stemming each word
    # in string array at ith row
    review = [ps.stem(word) for word in review
                if not word in set(stopwords.words('english'))]

    # rejoin all string array elements
    # to create back into a string
    review = ' '.join(review)

    # append each string to create
    # array of clean text
    corpus.append(review)

# %%
df['review'] = corpus
df.drop(columns=['text'])
df.info()
df.to_parquet('reviews_token.parquet')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643057 entries, 0 to 1643056
# Data columns (total 4 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1643057 non-null  float64
#  1   gmap_id  1643057 non-null  object
#  2   text     1643057 non-null  object
#  3   review   1643057 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 50.1+ MB
